# %%
import os
# %pwd
os.chdir("../")
# %pwd
# Out:
# 'd:\\Data Science\\END to END Proj\\DNAseqMLOPS'

# %%
# %pip install dagshub
import dagshub
dagshub.init(repo_owner='gowtham-dd', repo_name='DNAseqMLOPS', mlflow=True)

import mlflow
with mlflow.start_run():
  mlflow.log_param('parameter name', 'value')
  mlflow.log_metric('metric name', 1)
# Out:
# Collecting dagshub
#   Using cached dagshub-0.6.2-py3-none-any.whl (261 kB)
# Requirement already satisfied: PyYAML>=5 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub) (6.0.1)
# Collecting appdirs>=1.4.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: click>=8.0.4 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub) (8.2.1)
# Requirement already satisfied: httpx>=0.23.0 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub) (0.28.1)
# Requirement already satisfied: GitPython>=3.1.29 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub) (3.1.45)
# Collecting rich>=13.1.0
#   Downloading rich-14.1.0-py3-none-any.whl (243 kB)
#      -------------------------------------- 243.4/243.4 kB 1.7 MB/s eta 0:00:00
# Collecting dacite~=1.6.0
#   Using cached dacite-1.6.0-py3-none-any.whl (12 kB)
# Collecting tenacity>=8.2.2
#   Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting gql[requests]
#   Using cached gql-3.5.3-py2.py3-none-any.whl (74 kB)
# Collecting dataclasses-json
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: pandas in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub) (2.2.2)
# Collecting treelib>=1.6.4
#   Using cached treelib-1.8.0-py3-none-any.whl (30 kB)
# Collecting pathvalidate>=3.0.0
#   Using cached pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub) (2.9.0.post0)
# Collecting boto3
#   Downloading boto3-1.39.13-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.9/139.9 kB 1.4 MB/s eta 0:00:00
# Collecting semver
#   Using cached semver-3.0.4-py3-none-any.whl (17 kB)
# Collecting dagshub-annotation-converter>=0.1.5
#   Using cached dagshub_annotation_converter-0.1.11-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from click>=8.0.4->dagshub) (0.4.6)
# Collecting lxml
#   Using cached lxml-6.0.0-cp311-cp311-win_amd64.whl (4.0 MB)
# Requirement already satisfied: pillow in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub-annotation-converter>=0.1.5->dagshub) (11.3.0)
# Collecting pydantic>=2.0.0
#   Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Requirement already satisfied: typing-extensions in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from dagshub-annotation-converter>=0.1.5->dagshub) (4.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from GitPython>=3.1.29->dagshub) (4.0.12)
# Requirement already satisfied: anyio in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from httpx>=0.23.0->dagshub) (4.9.0)
# Requirement already satisfied: certifi in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from httpx>=0.23.0->dagshub) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from httpx>=0.23.0->dagshub) (1.0.9)
# Requirement already satisfied: idna in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from httpx>=0.23.0->dagshub) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->dagshub) (0.16.0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from rich>=13.1.0->dagshub) (2.19.2)
# Requirement already satisfied: six>=1.13.0 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from treelib>=1.6.4->dagshub) (1.17.0)
# Collecting botocore<1.40.0,>=1.39.13
#   Downloading botocore-1.39.13-py3-none-any.whl (13.9 MB)
#      -------------------------------------- 13.9/13.9 MB 792.4 kB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.14.0,>=0.13.0
#   Using cached s3transfer-0.13.1-py3-none-any.whl (85 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting graphql-core<3.2.7,>=3.2
#   Using cached graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Collecting yarl<2.0,>=1.6
#   Using cached yarl-1.20.1-cp311-cp311-win_amd64.whl (86 kB)
# Collecting backoff<3.0,>=1.11.1
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests<3,>=2.26 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from gql[requests]->dagshub) (2.32.4)
# Collecting requests-toolbelt<2,>=1.0.0
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: numpy>=1.23.2 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from pandas->dagshub) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from pandas->dagshub) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from pandas->dagshub) (2024.1)
# Requirement already satisfied: sniffio>=1.1 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from anyio->httpx>=0.23.0->dagshub) (1.3.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from botocore<1.40.0,>=1.39.13->boto3->dagshub) (2.5.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.29->dagshub) (5.0.2)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: packaging>=17.0 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->dagshub) (23.2)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.2
#   Using cached pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
# Collecting typing-inspection>=0.4.0
#   Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\data science\end to end proj\dnaseqmlops\venv\lib\site-packages (from requests<3,>=2.26->gql[requests]->dagshub) (3.4.2)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Collecting multidict>=4.0
#   Using cached multidict-6.6.3-cp311-cp311-win_amd64.whl (45 kB)
# Collecting propcache>=0.2.1
#   Using cached propcache-0.3.2-cp311-cp311-win_amd64.whl (41 kB)
# Installing collected packages: appdirs, typing-inspection, treelib, tenacity, semver, pydantic-core, propcache, pathvalidate, mypy-extensions, multidict, mdurl, marshmallow, lxml, jmespath, graphql-core, dacite, backoff, annotated-types, yarl, typing-inspect, requests-toolbelt, pydantic, markdown-it-py, botocore, s3transfer, rich, gql, dataclasses-json, dagshub-annotation-converter, boto3, dagshub
# Successfully installed annotated-types-0.7.0 appdirs-1.4.4 backoff-2.2.1 boto3-1.39.13 botocore-1.39.13 dacite-1.6.0 dagshub-0.6.2 dagshub-annotation-converter-0.1.11 dataclasses-json-0.6.7 gql-3.5.3 graphql-core-3.2.6 jmespath-1.0.1 lxml-6.0.0 markdown-it-py-3.0.0 marshmallow-3.26.1 mdurl-0.1.2 multidict-6.6.3 mypy-extensions-1.1.0 pathvalidate-3.3.1 propcache-0.3.2 pydantic-2.11.7 pydantic-core-2.33.2 requests-toolbelt-1.0.0 rich-14.1.0 s3transfer-0.13.1 semver-3.0.4 tenacity-9.1.2 treelib-1.8.0 typing-inspect-0.9.0 typing-inspection-0.4.1 yarl-1.20.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Accessing as gowtham-dd
# Initialized MLflow to track repo "gowtham-dd/DNAseqMLOPS"
# Repository gowtham-dd/DNAseqMLOPS initialized!

# %%
from dataclasses import dataclass
from pathlib import Path
@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    test_data_path: Path
    test_labels_path: Path
    model_dir: Path
    metric_file_name: Path
    mlflow_uri: str
    all_params: dict

# %%
from dataclasses import dataclass
from pathlib import Path
import numpy as np
import joblib
import json
import mlflow
from urllib.parse import urlparse
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from DNASeqMLOPS import logger
import os

# %%
from src.DNASeqMLOPS.utils.common import read_yaml, create_directories
from src.DNASeqMLOPS.constant import *

class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
        schema_filepath=SCHEMA_FILE_PATH
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])
        
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:
        config = self.config.model_evaluation
        
        return ModelEvaluationConfig(
            root_dir=Path(config.root_dir),
            test_data_path=Path(config.test_data_path),
            test_labels_path=Path(config.test_labels_path),
            model_dir=Path(config.model_dir),
            metric_file_name=Path(config.metric_file_name),
            mlflow_uri=config.mlflow_uri,
            all_params=self.params.model_training  # All model params from params.yaml
        )

# %%
from dataclasses import dataclass
from pathlib import Path
import numpy as np
import joblib
import json
import mlflow
import os
from urllib.parse import urlparse
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from DNASeqMLOPS import logger



class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig):
        self.config = config
        # Create evaluation directory if it doesn't exist
        os.makedirs(self.config.root_dir, exist_ok=True)

    def _load_test_data(self):
        """Load test features and labels"""
        try:
            X_test = np.load(self.config.test_data_path)
            y_test = np.load(self.config.test_labels_path)
            return X_test, y_test
        except Exception as e:
            logger.error(f"Error loading test data: {e}")
            raise

    def _load_models(self):
        """Load all trained models"""
        models = {}
        try:
            for model_file in os.listdir(self.config.model_dir):
                if model_file.endswith('.joblib'):
                    model_name = model_file.split('.')[0]
                    model_path = os.path.join(self.config.model_dir, model_file)
                    models[model_name] = joblib.load(model_path)
            return models
        except Exception as e:
            logger.error(f"Error loading models: {e}")
            raise

    def evaluate_models(self):
        """Evaluate all models and return metrics"""
        try:
            X_test, y_test = self._load_test_data()
            models = self._load_models()
            
            metrics = {}
            for model_name, model in models.items():
                try:
                    y_pred = model.predict(X_test)
                    
                    metrics[model_name] = {
                        'accuracy': accuracy_score(y_test, y_pred),
                        'f1_score': f1_score(y_test, y_pred),
                        'classification_report': classification_report(y_test, y_pred, output_dict=True),
                        'confusion_matrix': confusion_matrix(y_test, y_pred).tolist()
                    }
                    logger.info(f"\n{model_name} Evaluation:\n{json.dumps(metrics[model_name], indent=2)}")
                except Exception as e:
                    logger.error(f"Error evaluating {model_name}: {e}")
                    continue
            
            return metrics
        except Exception as e:
            logger.error(f"Evaluation failed: {e}")
            raise

    def _save_metrics(self, metrics):
        """Save metrics to JSON file"""
        try:
            with open(self.config.metric_file_name, 'w') as f:
                json.dump(metrics, f, indent=4)
            logger.info(f"Metrics saved to {self.config.metric_file_name}")
        except Exception as e:
            logger.error(f"Error saving metrics: {e}")
            raise

    def log_into_mlflow(self):
        """Log evaluation results to MLflow"""
        try:
            if not os.path.exists(self.config.metric_file_name):
                mlflow.set_tracking_uri(self.config.mlflow_uri)
                tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme

                with mlflow.start_run():
                    # Evaluate models
                    metrics = self.evaluate_models()
                    
                    # Save metrics to file
                    self._save_metrics(metrics)
                    
                    # Log parameters and metrics
                    mlflow.log_params(self.config.all_params)
                    for model_name, model_metrics in metrics.items():
                        for metric_name, value in model_metrics.items():
                            if isinstance(value, (int, float)):
                                mlflow.log_metric(f"{model_name}_{metric_name}", value)
                    
                    # Log models
                    if tracking_url_type_store != "file":
                        models = self._load_models()
                        for model_name, model in models.items():
                            try:
                                if hasattr(model, 'predict'):
                                    mlflow.sklearn.log_model(
                                        sk_model=model,
                                        artifact_path=f"{model_name}_model",
                                        registered_model_name=f"DNA_Seq_{model_name}"
                                    )
                            except Exception as e:
                                logger.error(f"Error logging {model_name} to MLflow: {e}")
                    
                    logger.info("Evaluation results logged to MLflow")
                return True
            else:
                logger.info(f"Metrics file {self.config.metric_file_name} already exists - skipping evaluation")
                return False
        except Exception as e:
            logger.error(f"MLflow logging failed: {e}")
            raise

# %%
try:
    config = ConfigurationManager()
    eval_config = config.get_model_evaluation_config()
    evaluator = ModelEvaluation(eval_config)
    
    if evaluator.log_into_mlflow():
        logger.info("New evaluation performed and logged")
    else:
        logger.info("Using existing evaluation results")
        
except Exception as e:
    logger.error(f"Model evaluation failed: {e}")
    raise
# Out:
# [2025-07-25 17:36:14,575: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-07-25 17:36:14,588: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-07-25 17:36:14,595: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-07-25 17:36:14,601: INFO: common: created directory at: artifacts]
# [2025-07-25 17:36:14,787: WARNING: connectionpool: Retrying (Retry(total=4, connect=5, read=4, redirect=5, status=5)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /gowtham-dd/DNAseqMLOPS.mlflow/api/2.0/mlflow/runs/create]
# [2025-07-25 17:36:20,752: INFO: 3732966409:
# RandomForest Evaluation:
# {
#   "accuracy": 0.98906,
#   "f1_score": 0.9889992760035395,
#   "classification_report": {
#     "0": {
#       "precision": 0.9849472162253164,
#       "recall": 0.9933284062081777,
#       "f1-score": 0.9891200572837935,
#       "support": 50063.0
#     },
#     "1": {
#       "precision": 0.9932540243582234,
#       "recall": 0.9847808238380359,
#       "f1-score": 0.9889992760035395,
#       "support": 49937.0
#     },
#     "accuracy": 0.98906,
#     "macro avg": {
#       "precision": 0.9891006202917699,
#       "recall": 0.9890546150231068,
#       "f1-score": 0.9890596666436665,
#       "support": 100000.0
#     },
#     "weighted avg": {
#       "precision": 0.9890953870026462,
#       "recall": 0.98906,
#       "f1-score": 0.9890597427358732,
#       "support": 100000.0
#     }
#   },
#   "confusion_matrix": [
#     [
#       49729,
#       334
#     ],
#     [
#       760,
#       49177
#     ]
#   ]
# }]
# [2025-07-25 17:38:54,632: INFO: 3732966409:
# SVM Evaluation:
# {
#   "accuracy": 0.98325,
#   "f1_score": 0.9831500799742473,
#   "classification_report": {
#     "0": {
#       "precision": 0.9788046704927765,
#       "recall": 0.9879352016459262,
#       "f1-score": 0.9833487419601762,
#       "support": 50063.0
#     },
#     "1": {
#       "precision": 0.9877905801495857,
#       "recall": 0.9785529767507058,
#       "f1-score": 0.9831500799742473,
#       "support": 49937.0
#     },
#     "accuracy": 0.98325,
#     "macro avg": {
#       "precision": 0.9832976253211811,
#       "recall": 0.9832440891983161,
#       "f1-score": 0.9832494109672117,
#       "support": 100000.0
#     },
#     "weighted avg": {
#       "precision": 0.9832919641980973,
#       "recall": 0.98325,
#       "f1-score": 0.9832495361242629,
#       "support": 100000.0
#     }
#   },
#   "confusion_matrix": [
#     [
#       49459,
#       604
#     ],
#     [
#       1071,
#       48866
#     ]
#   ]
# }]
# [2025-07-25 17:38:54,632: ERROR: 3732966409: Error evaluating training_results: 'dict' object has no attribute 'predict']
# [2025-07-25 17:38:55,515: INFO: 3732966409:
# XGBoost Evaluation:
# {
#   "accuracy": 0.99451,
#   "f1_score": 0.9944904410657835,
#   "classification_report": {
#     "0": {
#       "precision": 0.9922651713990297,
#       "recall": 0.9968040269260732,
#       "f1-score": 0.9945294205570225,
#       "support": 50063.0
#     },
#     "1": {
#       "precision": 0.9967812022209704,
#       "recall": 0.9922101848328895,
#       "f1-score": 0.9944904410657835,
#       "support": 49937.0
#     },
#     "accuracy": 0.99451,
#     "macro avg": {
#       "precision": 0.9945231868100001,
#       "recall": 0.9945071058794813,
#       "f1-score": 0.994509930811403,
#       "support": 100000.0
#     },
#     "weighted avg": {
#       "precision": 0.9945203417105822,
#       "recall": 0.99451,
#       "f1-score": 0.9945099553684826,
#       "support": 100000.0
#     }
#   },
#   "confusion_matrix": [
#     [
#       49903,
#       160
#     ],
#     [
#       389,
#       49548
#     ]
#   ]
# }]
# [2025-07-25 17:38:55,533: INFO: 3732966409: Metrics saved to artifacts\model_evaluation\metrics.json]
# d:\Data Science\END to END Proj\DNAseqMLOPS\venv\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'DNA_Seq_RandomForest'.
# 2025/07/25 17:41:02 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: DNA_Seq_RandomForest, version 1
# Created version '1' of model 'DNA_Seq_RandomForest'.
# Successfully registered model 'DNA_Seq_SVM'.
# 2025/07/25 17:41:43 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: DNA_Seq_SVM, version 1
# Created version '1' of model 'DNA_Seq_SVM'.
# Successfully registered model 'DNA_Seq_XGBoost'.
# 2025/07/25 17:42:00 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: DNA_Seq_XGBoost, version 1
# [2025-07-25 17:42:00,698: INFO: 3732966409: Evaluation results logged to MLflow]
# Created version '1' of model 'DNA_Seq_XGBoost'.
# [2025-07-25 17:42:01,330: INFO: 3201019539: New evaluation performed and logged]
